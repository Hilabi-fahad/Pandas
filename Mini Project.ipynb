# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <h6>SaleData is import </h6>

# %%
df=pd.read_excel('salereport.xlsx')
df
# Out:
#           Chain  Potcode     Category  T.U     C.P     S.P
# 0    Ready Wear     2650         Home  175    2.78    6.35
# 1    Ready Wear     3550    Groceries  908    0.61    0.93
# 2    Ready Wear     4053         Home    1  500.00  750.00
# 3    Ready Wear     3076    Groceries  714    1.14    1.46
# 4    Ready Wear     2031    Groceries   65    0.48    3.90
# 5    Ready Wear     3066         Home   87    3.66    6.19
# 6    Ready Wear     2067         Home   92    5.21    7.34
# 7    Ready Wear     2800         Home   21    4.49   13.55
# 8    Ready Wear     2560         Home  127    4.19    5.59
# 9    Ready Wear     3076         Home   77    4.73    6.99
# 10   Ready Wear      800       Womens    2   10.00   18.53
# 11   Ready Wear     2031    Groceries  898    1.20    1.39
# 12   Ready Wear     4068         Home  170    4.15    5.13
# 13   Ready Wear      800       Womens   50    1.90    1.92
# 14   Ready Wear     4068       Womens  166    2.51    3.43
# ...

# %% [markdown]
# <h6>Renaming the columns</h6>

# %%
df.rename(columns={"Potcode": "Postcode", "T.U": "Total Unit" ,"S.P": "Sales Price", "C.P": "Cost Price"},inplace=True)

# %%
df
# Out:
#           Chain  Postcode     Category  Total Unit  Cost Price  Sales Price
# 0    Ready Wear      2650         Home         175        2.78         6.35
# 1    Ready Wear      3550    Groceries         908        0.61         0.93
# 2    Ready Wear      4053         Home           1      500.00       750.00
# 3    Ready Wear      3076    Groceries         714        1.14         1.46
# 4    Ready Wear      2031    Groceries          65        0.48         3.90
# 5    Ready Wear      3066         Home          87        3.66         6.19
# 6    Ready Wear      2067         Home          92        5.21         7.34
# 7    Ready Wear      2800         Home          21        4.49        13.55
# 8    Ready Wear      2560         Home         127        4.19         5.59
# 9    Ready Wear      3076         Home          77        4.73         6.99
# 10   Ready Wear       800       Womens           2       10.00        18.53
# ...

# %%
df.dtypes
# Out:
# Chain           object
# Postcode         int64
# Category        object
# Total Unit       int64
# Cost Price     float64
# Sales Price    float64
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <h6>Searching for Null Values</h6>

# %%
df.isnull()
# Out:
#      Chain  Postcode  Category  Total Unit  Cost Price  Sales Price
# 0    False     False     False       False       False        False
# 1    False     False     False       False       False        False
# 2    False     False     False       False       False        False
# 3    False     False     False       False       False        False
# 4    False     False     False       False       False        False
# 5    False     False     False       False       False        False
# 6    False     False     False       False       False        False
# 7    False     False     False       False       False        False
# 8    False     False     False       False       False        False
# 9    False     False     False       False       False        False
# 10   False     False     False       False       False        False
# 11   False     False     False       False       False        False
# 12   False     False     False       False       False        False
# ...

# %%
df.shape
# Out:
# (899, 6)

# %%
df.head()
# Out:
#         Chain  Postcode   Category  Total Unit  Cost Price  Sales Price
# 0  Ready Wear      2650       Home         175        2.78         6.35
# 1  Ready Wear      3550  Groceries         908        0.61         0.93
# 2  Ready Wear      4053       Home           1      500.00       750.00
# 3  Ready Wear      3076  Groceries         714        1.14         1.46
# 4  Ready Wear      2031  Groceries          65        0.48         3.90

# %%
df.T
# Out:
#                     0           1           2           3           4    \
# Chain        Ready Wear  Ready Wear  Ready Wear  Ready Wear  Ready Wear
# Postcode           2650        3550        4053        3076        2031
# Category           Home   Groceries        Home   Groceries   Groceries
# Total Unit          175         908           1         714          65
# Cost Price         2.78        0.61         500        1.14        0.48
# Sales Price        6.35        0.93         750        1.46         3.9
#
#                     5           6           7           8           9    ...  \
# Chain        Ready Wear  Ready Wear  Ready Wear  Ready Wear  Ready Wear  ...
# Postcode           3066        2067        2800        2560        3076  ...
# Category           Home        Home        Home        Home        Home  ...
# Total Unit           87          92          21         127          77  ...
# Cost Price         3.66        5.21        4.49        4.19        4.73  ...
# ...

# %% [markdown]
# <h6>Arithmetic Operations</h6>

# %%
df['Total Cost']=df['Total Unit']*df['Cost Price']
df['Total Sales']=df['Total Unit']*df['Sales Price']
df['Profit']=df['Total Sales']-df['Total Cost']

# %%
df.head(10)
# Out:
#         Chain  Postcode   Category  Total Unit  Cost Price  Sales Price  \
# 0  Ready Wear      2650       Home         175        2.78         6.35
# 1  Ready Wear      3550  Groceries         908        0.61         0.93
# 2  Ready Wear      4053       Home           1      500.00       750.00
# 3  Ready Wear      3076  Groceries         714        1.14         1.46
# 4  Ready Wear      2031  Groceries          65        0.48         3.90
# 5  Ready Wear      3066       Home          87        3.66         6.19
# 6  Ready Wear      2067       Home          92        5.21         7.34
# 7  Ready Wear      2800       Home          21        4.49        13.55
# 8  Ready Wear      2560       Home         127        4.19         5.59
# 9  Ready Wear      3076       Home          77        4.73         6.99
#
#    Total Cost  Total Sales  Profit
# 0      486.50      1111.25  624.75
# 1      553.88       844.44  290.56
# 2      500.00       750.00  250.00
# ...

# %%
df.describe()
# Out:
#           Postcode   Total Unit  Cost Price  Sales Price   Total Cost  \
# count   899.000000   899.000000  899.000000   899.000000   899.000000
# mean   3658.364850    29.726363    5.353204     5.774093   105.676474
# std    1562.458905   113.527165   17.001521    25.171068   361.789792
# min     800.000000    -3.000000  -22.970000     0.250000   -42.970000
# 25%    2560.000000     1.000000    2.000000     1.910000     5.990000
# 50%    3429.000000     5.000000    4.000000     3.800000    17.000000
# 75%    4680.000000    15.500000    7.000000     7.000000    68.080000
# max    7320.000000  1674.000000  500.000000   750.000000  5213.560000
#
#        Total Sales       Profit
# count   899.000000   899.000000
# mean    100.945751    -4.730723
# std     279.311595   119.046111
# min     -20.000000 -1771.250000
# 25%       4.500000    -2.750000
# 50%      19.210000     0.000000
# 75%      76.745000     8.000000
# max    4039.200000   624.750000
